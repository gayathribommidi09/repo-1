# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathribommidi09/repo-1/blob/main/student_grade_management_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-17-jdk-headless -qq > /dev/null

# %%
# !java -version
# Out:
# openjdk version "17.0.18" 2026-01-20
# OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-122.04.1, mixed mode, sharing)

# %%
# %%writefile GradeManagementSystem.java
# import java.util.Scanner;
#
# class Student {
#     String name;
#     int[] marks = new int[3];
#     double average;
#     String grade;
#
#     void inputDetails() {
#         Scanner sc = new Scanner(System.in);
#
#         System.out.print("Enter Student Name: ");
#         name = sc.nextLine();
#
#         System.out.println("Enter marks of 3 subjects:");
#         for (int i = 0; i < 3; i++) {
#             System.out.print("Subject " + (i + 1) + ": ");
#             marks[i] = sc.nextInt();
#         }
#     }
#
#     void calculateResult() {
#         int total = 0;
#
#         for (int m : marks) {
#             total += m;
#         }
#
#         average = total / 3.0;
#
#         if (average >= 80) grade = "A";
#         else if (average >= 60) grade = "B";
#         else if (average >= 40) grade = "C";
#         else grade = "Fail";
#     }
#
#     void displayReport() {
#         System.out.println("\n----- Student Report -----");
#         System.out.println("Name: " + name);
#         for (int i = 0; i < 3; i++) {
#             System.out.println("Subject " + (i+1) + ": " + marks[i]);
#         }
#         System.out.println("Average: " + average);
#         System.out.println("Grade: " + grade);
#         System.out.println("--------------------------");
#     }
# }
#
# public class GradeManagementSystem {
#     public static void main(String[] args) {
#         Student s1 = new Student();
#         s1.inputDetails();
#         s1.calculateResult();
#         s1.displayReport();
#     }
# }
# Out:
# Writing GradeManagementSystem.java

# %%
# !javac GradeManagementSystem.java

# %%
# !java GradeManagementSystem
# Out:
# Enter Student Name: rakesh
# Enter marks of 3 subjects:
# Subject 1: 78
# Subject 2: 80
# Subject 3: 67
#
# ----- Student Report -----
# Name: rakesh
# Subject 1: 78
# Subject 2: 80
# Subject 3: 67
# Average: 75.0
# Grade: B
# --------------------------
