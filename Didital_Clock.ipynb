# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathribommidi09/repo-1/blob/main/Didital_Clock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install openjdk-17-jdk -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libgail-common libgail18 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common librsvg2-common libxcomposite1 libxt-dev
#   libxtst6 libxxf86dga1 openjdk-17-jre session-migration x11-utils
# Suggested packages:
#   gvfs libxt-doc openjdk-17-demo openjdk-17-source visualvm mesa-utils
# The following NEW packages will be installed:
#   at-spi2-core fonts-dejavu-core fonts-dejavu-extra gsettings-desktop-schemas
#   libatk-bridge2.0-0 libatk-wrapper-java libatk-wrapper-java-jni libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libgail-common libgail18 libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common librsvg2-common libxcomposite1 libxt-dev
# ...

# %%
# !java -version
# Out:
# openjdk version "17.0.18" 2026-01-20
# OpenJDK Runtime Environment (build 17.0.18+8-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 17.0.18+8-Ubuntu-122.04.1, mixed mode, sharing)

# %%
# %%writefile DigitalClock.java
# import java.util.Date;
#
# class DigitalClock extends Thread {
#
#     public void run() {
#         while (true) {
#             Date now = new Date();  // get current system time
#
#             // Display time in HH:MM:SS format
#             String time = String.format("%tT", now);
#             System.out.println("Current Time: " + time);
#
#             try {
#                 Thread.sleep(1000); // update every second
#             } catch (InterruptedException e) {
#                 System.out.println("Clock interrupted");
#             }
#         }
#     }
#
#     public static void main(String[] args) {
#         DigitalClock clock = new DigitalClock();
#         clock.start();  // start the thread
#     }
# }
# Out:
# Writing DigitalClock.java

# %%
# !javac DigitalClock.java

# %%
# !java DigitalClock
# Out:
# Current Time: 04:08:37
# Current Time: 04:08:38
# Current Time: 04:08:39
# Current Time: 04:08:40
# Current Time: 04:08:41
# Current Time: 04:08:42
# Current Time: 04:08:43
# Current Time: 04:08:44
# Current Time: 04:08:45
# Current Time: 04:08:46
# Current Time: 04:08:47
# Current Time: 04:08:48
# Current Time: 04:08:49
# Current Time: 04:08:50
# Current Time: 04:08:51
# Current Time: 04:08:52
# Current Time: 04:08:53
# Current Time: 04:08:54
# Current Time: 04:08:55
# Current Time: 04:08:56
# Current Time: 04:08:57
# Current Time: 04:08:58
# Current Time: 04:08:59
# Current Time: 04:09:00
# Current Time: 04:09:01
# Current Time: 04:09:02
# Current Time: 04:09:03
# Current Time: 04:09:04
# Current Time: 04:09:05
# Current Time: 04:09:06
# Current Time: 04:09:07
# Current Time: 04:09:08
# Current Time: 04:09:09
# Current Time: 04:09:10
# Current Time: 04:09:11
# Current Time: 04:09:12
# Current Time: 04:09:13
# Current Time: 04:09:14
# Current Time: 04:09:15
# Current Time: 04:09:16
# ...
